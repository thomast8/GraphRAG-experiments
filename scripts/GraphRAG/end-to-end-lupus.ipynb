# %% [markdown]
# # GraphRAG Python package End-to-End Example
#
# This notebook contains an end-to-end worked example using the [GraphRAG Python package](https://neo4j.com/docs/neo4j-graphrag-python/current/index.html) for Neo4j. It starts with unstructured documents (in this case pdfs), and progresses through knowledge graph construction, knowledge graph retriever design, and complete GraphRAG pipelines.
#
# Research papers on Lupus are used as the data source. We design a couple of different retrievers based on different knowledge graph retrieval patterns.
#
# For more details and explanations around each of the below steps, see the [corresponding blog post](https://neo4j.com/blog/graphrag-python-package/) which contains a full write-up, in-depth comparison of the retrieval patterns, and additional learning resources.
#
# ## Pre-Requisites
#
# 1. __Create a Neo4j Database__: To work through this RAG example, you need a database for storing and retrieving data. There are many options for this. You can quickly start a free Neo4j Graph Database using [Neo4j AuraDB](https://neo4j.com/product/auradb/?ref=neo4j-home-hero). You can use __AuraDB Free__ or start an __AuraDB Professional (Pro) free trial__ for higher ingestion and retrieval performance. The Pro instances have a bit more RAM; we recommend them for the best user experience.
# 2. __Obtain an OpenAI Key__: This example requires an OpenAI API key to use language models and embedders. The cost should be very minimal. If you do not yet have an OpenAI API key you can [create an OpenAI account](https://platform.openai.com/signup) or [sign in](https://platform.openai.com/login). Next, navigate to the [API key page](https://platform.openai.com/account/api-keys) and click "Create new secret key". Optionally naming the key.
# 3. __Fill in Credentials__: Either by copying the [`.env.template`](.env.template) file, naming it `.env`, and filling in the appropriate credentials, or by manually putting the credentials into the second code cell below. You will need:
#     1. The Neo4j URI, username, and password variables from when you created the database. If you created your database on AuraDB, they are in the file you downloaded.
#     2. Your OpenAI API key.

# %% [markdown]
# ## Setup

# %%
# %%capture
# %pip install fsspec langchain-text-splitters tiktoken openai python-dotenv numpy torch neo4j-graphrag

# %%
from dotenv import load_dotenv
import os

# load neo4j credentials (and openai api key in background).
load_dotenv('.env', override=True)
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "password"

#uncomment this line if you aren't using a .env file
os.environ['OPENAI_API_KEY'] = "<your-openai-api-key>"

# %% [markdown]
# ## Knowledge Graph Building
#
# The `SimpleKGPipeline` class allows you to automatically build a knowledge graph with a few key inputs, including
# - a driver to connect to Neo4j,
# - an LLM for entity extraction, and
# - an embedding model to create vectors on text chunks for similarity search.
#
# There are also some optional inputs, such as node labels, relationship types, and a custom prompt template, which we will use to improve the quality of the knowledge graph. For full details on this, see [the blog](https://neo4j.com/blog/graphrag-python-package/).

# %%
import neo4j
from neo4j_graphrag.llm import OpenAILLM
from neo4j_graphrag.embeddings.openai import OpenAIEmbeddings

driver = neo4j.GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

ex_llm=OpenAILLM(
    model_name="gpt-5-nano",
    model_params={
            "reasoning":{ "effort": "low" },
    "text":{ "verbosity": "low" },
        "response_format": {"type": "json_object"}, # use json_object formatting for best results
    }
)

#create text embedder
embedder = OpenAIEmbeddings()

# %%
#define node labels
basic_node_labels = ["Object", "Entity", "Group", "Person", "Organization", "Place"]

academic_node_labels = ["ArticleOrPaper", "PublicationOrJournal"]

medical_node_labels = ["Anatomy", "BiologicalProcess", "Cell", "CellularComponent", 
                       "CellType", "Condition", "Disease", "Drug",
                       "EffectOrPhenotype", "Exposure", "GeneOrProtein", "Molecule",
                       "MolecularFunction", "Pathway"]

node_labels = basic_node_labels + academic_node_labels + medical_node_labels

# define relationship types
rel_types = ["ACTIVATES", "AFFECTS", "ASSESSES", "ASSOCIATED_WITH", "AUTHORED",
    "BIOMARKER_FOR", "CAUSES", "CITES", "CONTRIBUTES_TO", "DESCRIBES", "EXPRESSES",
    "HAS_REACTION", "HAS_SYMPTOM", "INCLUDES", "INTERACTS_WITH", "PRESCRIBED",
    "PRODUCES", "RECEIVED", "RESULTS_IN", "TREATS", "USED_FOR"]

# %%
prompt_template = '''
You are a medical researcher tasks with extracting information from papers 
and structuring it in a property graph to inform further medical and research Q&A.

Extract the entities (nodes) and specify their type from the following Input text.
Also extract the relationships between these nodes. the relationship direction goes from the start node to the end node. 


Return result as JSON using the following format:
{{"nodes": [ {{"id": "0", "label": "the type of entity", "properties": {{"name": "name of entity" }} }}],
  "relationships": [{{"type": "TYPE_OF_RELATIONSHIP", "start_node_id": "0", "end_node_id": "1", "properties": {{"details": "Description of the relationship"}} }}] }}

- Use only the information from the Input text.  Do not add any additional information.  
- If the input text is empty, return empty Json. 
- Make sure to create as many nodes and relationships as needed to offer rich medical context for further research.
- An AI knowledge assistant must be able to read this graph and immediately understand the context to inform detailed research questions. 
- Multiple documents will be ingested from different sources and we are using this property graph to connect information, so make sure entity types are fairly general. 

Use only fhe following nodes and relationships (if provided):
{schema}

Assign a unique ID (string) to each node, and reuse it to define relationships.
Do respect the source and target node types for relationship and
the relationship direction.

Do not return any additional information other than the JSON in it.

Examples:
{examples}

Input text:

{text}
'''

# %%
from neo4j_graphrag.experimental.components.text_splitters.fixed_size_splitter import FixedSizeSplitter
from neo4j_graphrag.experimental.pipeline.kg_builder import SimpleKGPipeline

kg_builder_pdf = SimpleKGPipeline(
    llm=ex_llm,
    driver=driver,
    text_splitter=FixedSizeSplitter(chunk_size=500, chunk_overlap=100),
    embedder=embedder,
    entities=node_labels,
    relations=rel_types,
    prompt_template=prompt_template,
    from_pdf=True
)

# %% [markdown]
# Below, we run the `SimpleKGPipeline` to construct our knowledge graph from 3 pdf documents and store in Neo4j.

# %%
pdf_file_paths = ['truncated-pdfs/biomolecules-11-00928-v2-trunc.pdf', 
             'truncated-pdfs/GAP-between-patients-and-clinicians_2023_Best-Practice-trunc.pdf', 
             'truncated-pdfs/pgpm-13-39-trunc.pdf']

for path in pdf_file_paths:
    print(f"Processing : {path}")
    pdf_result = await kg_builder_pdf.run_async(file_path=path)
    print(f"Result: {pdf_result}")
# Out:
# Processing : truncated-pdfs/biomolecules-11-00928-v2-trunc.pdf
# Result: run_id='e868e9d8-d820-44b6-b1cd-43c3db3164a5' result={'resolver': {'number_of_nodes_to_resolve': 1396, 'number_of_created_nodes': 1075}}
# Processing : truncated-pdfs/GAP-between-patients-and-clinicians_2023_Best-Practice-trunc.pdf
# Result: run_id='3043c3fb-0814-4900-8657-a1292108ba3d' result={'resolver': {'number_of_nodes_to_resolve': 2137, 'number_of_created_nodes': 1861}}
# Processing : truncated-pdfs/pgpm-13-39-trunc.pdf
# Result: run_id='c55aa526-81e3-4051-9e11-be68c473f8c7' result={'resolver': {'number_of_nodes_to_resolve': 3176, 'number_of_created_nodes': 2873}}

# %% [markdown]
# ## Knowledge Graph Retrieval

# %% [markdown]
# We will leverage Neo4j's vector search capabilities here. To do this, we need to begin by creating a vector index on the text chunks from the PDFs, which are stored on `Chunk` nodes in our knowledge graph.

# %%
from neo4j_graphrag.indexes import create_vector_index

create_vector_index(driver, name="text_embeddings", label="Chunk",
                    embedding_property="embedding", dimensions=1536, similarity_fn="cosine")

# %% [markdown]
# Now that the index is set up, we will start simple with a __VectorRetriever__.  The __VectorRetriever__ just queries `Chunk` nodes via vector search, bringing back the text and some metadata.

# %%
from neo4j_graphrag.retrievers import VectorRetriever

vector_retriever = VectorRetriever(
    driver,
    index_name="text_embeddings",
    embedder=embedder,
    return_properties=["text"],
)

# %% [markdown]
# Below we visualize the context we get back when submitting a search prompt.

# %%
import json

vector_res = vector_retriever.get_search_results(query_text = "How is precision medicine applied to Lupus?", 
                                                 top_k=3)
for i in vector_res.records: print("====\n" + json.dumps(i.data(), indent=4))
# Out:
# ====
# {
#     "node": {
#         "text": "well-tolerated IS agents.\nPrecision medicine consists of a tailored approach to\neach patient, based on genetic and epigenetic singularities,\nwhich in \ufb02uence disease pathophysiology and drug\nresponse. Precision medicine in SLE is trying to address\nthe need to assess SLE patients optimally, predict disease\ncourse and treatment response at diagnosis. Ideally every\npatient would undergo an initial evaluation that would\npro\ufb01le his/her disease, assessing the main pathophysiolo-\ngic pathway through "
#     },
#     "nodeLabels": [
#         "__KGBuilder__",
#         "Chunk"
#     ],
#     "elementId": "4:70ee5e8d-7a46-4dd8-b9af-69df09d03890:2104",
#     "id": "4:70ee5e8d-7a46-4dd8-b9af-69df09d03890:2104",
#     "score": 0.9471129179000854
# }
# ====
# {
#     "node": {
#         "text": "gene signature has\nbeen shown to assist response prediction.77\nIn the current treatment of lupus longterm clinical and\nimmunological remission is only achieved in a proportion\nof patients. The inherent pathophysiological complexity of\nlupus described at the cellular and molecular level cannot\nbe overstated. Using targeted drug therapy and improving\nclinical assessment remains vital to improving disease\ncontrol and patient outcomes.\nThe Challenge of Moving T owards\nPrecision Medicine in SLE\nAs "
#     },
#     "nodeLabels": [
#         "__KGBuilder__",
#         "Chunk"
#     ],
#     "elementId": "4:70ee5e8d-7a46-4dd8-b9af-69df09d03890:2330",
#     "id": "4:70ee5e8d-7a46-4dd8-b9af-69df09d03890:2330",
#     "score": 0.937965989112854
# }
# ====
# {
#     "node": {
#         "text": "atients need\na careful balance of immunosuppression that controls the\ndisease without rendering them too susceptible to infection\nand long-term risks such as increased cardiovascular risk.\nOur approach as detailed in Table 1 does not help in\ndistinguishing subgroups of patients for methotrexate or\nazathioprine. The molecular tools for this are on their way\nto the clinic. In rheumatoid arthritis gene signature has\nbeen shown to assist response prediction.77\nIn the current treatment of lupus "
#     },
#     "nodeLabels": [
#         "__KGBuilder__",
#         "Chunk"
#     ],
#     "elementId": "4:70ee5e8d-7a46-4dd8-b9af-69df09d03890:2329",
#     "id": "4:70ee5e8d-7a46-4dd8-b9af-69df09d03890:2329",
#     "score": 0.9363570213317871
# }

# %% [markdown]
# The GraphRAG Python Package offers [a wide range of useful retrievers](https://neo4j.com/docs/neo4j-graphrag-python/current/user_guide_rag.html#retriever-configuration), each covering different knowledge graph retrieval patterns.
#
# Below we will use the __`VectorCypherRetriever`__, which allows you to run a graph traversal after finding nodes with vector search.  This uses Cypher, Neo4j's graph query language, to define the logic for traversing the graph.
#
# As a simple starting point, we'll traverse up to 3 hops out from each Chunk, capture the relationships encountered, and include them in the response alongside our text chunks.

# %%
from neo4j_graphrag.retrievers import VectorCypherRetriever

vc_retriever = VectorCypherRetriever(
    driver,
    index_name="text_embeddings",
    embedder=embedder,
    retrieval_query="""
//1) Go out 2-3 hops in the entity graph and get relationships
WITH node AS chunk
MATCH (chunk)<-[:FROM_CHUNK]-()-[relList:!FROM_CHUNK]-{1,2}()
UNWIND relList AS rel

//2) collect relationships and text chunks
WITH collect(DISTINCT chunk) AS chunks, 
  collect(DISTINCT rel) AS rels

//3) format and return context
RETURN '=== text ===\n' + apoc.text.join([c in chunks | c.text], '\n---\n') + '\n\n=== kg_rels ===\n' +
  apoc.text.join([r in rels | startNode(r).name + ' - ' + type(r) + '(' + coalesce(r.details, '') + ')' +  ' -> ' + endNode(r).name ], '\n---\n') AS info
"""
)

# %% [markdown]
# Below we visualize the context we get back when submitting a search prompt.

# %%
vc_res = vc_retriever.get_search_results(query_text = "How is precision medicine applied to Lupus?", top_k=3)

# print output
kg_rel_pos = vc_res.records[0]['info'].find('\n\n=== kg_rels ===\n')
print("# Text Chunk Context:")
print(vc_res.records[0]['info'][:kg_rel_pos])
print("# KG Context From Relationships:")
print(vc_res.records[0]['info'][kg_rel_pos:])
# Out:
# # Text Chunk Context:
# === text ===
# well-tolerated IS agents.
# Precision medicine consists of a tailored approach to
# each patient, based on genetic and epigenetic singularities,
# which in ﬂuence disease pathophysiology and drug
# response. Precision medicine in SLE is trying to address
# the need to assess SLE patients optimally, predict disease
# course and treatment response at diagnosis. Ideally every
# patient would undergo an initial evaluation that would
# proﬁle his/her disease, assessing the main pathophysiolo-
# gic pathway through
# ---
# gene signature has
# been shown to assist response prediction.77
# In the current treatment of lupus longterm clinical and
# immunological remission is only achieved in a proportion
# of patients. The inherent pathophysiological complexity of
# lupus described at the cellular and molecular level cannot
# be overstated. Using targeted drug therapy and improving
# clinical assessment remains vital to improving disease
# control and patient outcomes.
# The Challenge of Moving T owards
# Precision Medicine in SLE
# As
# ---
# atients need
# a careful balance of immunosuppression that controls the
# disease without rendering them too susceptible to infection
# and long-term risks such as increased cardiovascular risk.
# Our approach as detailed in Table 1 does not help in
# distinguishing subgroups of patients for methotrexate or
# azathioprine. The molecular tools for this are on their way
# to the clinic. In rheumatoid arthritis gene signature has
# been shown to assist response prediction.77
# In the current treatment of lupus
# # KG Context From Relationships:
#
#
# === kg_rels ===
# Biomarkers for SLE Diagnosis and Classification - DESCRIBES(section header about biomarkers for SLE diagnosis and classification) -> SLE
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> double-stranded DNA
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> immunoglobulin G
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> interferon
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> interleukin
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> IFN-γ-inducible protein 10
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> monocyte chemotactic protein-1
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> monocyte-to-high-density lipoprotein cholesterol ratio
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> low-density granulocytes-to-high-density lipoprotein cholesterol ratio
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> antibodies against paraoxonase1
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> Smith
# ---
# Biomarkers for SLE Diagnosis and Classification - INCLUDES(section includes this biomarker) -> tumor necrosis factor
# ---
# classification criteria of SLE - DESCRIBES(classification criteria describe SLE) -> SLE
# ---
# American College of Rheumatology (ACR) - AUTHORED(ACR established the most widely used classification criteria for SLE) -> classification criteria of SLE
# ---
# classification criteria of SLE - INCLUDES(the classification criteria contains laboratory biomarkers) -> laboratory biomarkers
# ---
# classification criteria of SLE - USED_FOR(classification criteria are necessary for research) -> research
# ---
# classification criteria of SLE - USED_FOR(classification criteria are necessary for clinical diagnosis) -> clinical diagnosis
# ---
# EULAR/ACR-2019 SLE classification - DESCRIBES(EULAR/ACR-2019 is a classification criteria for SLE developed in 2019) -> SLE
# ---
# American College of Rheumatology (ACR) - AUTHORED(ACR developed the 2019 SLE classification) -> EULAR/ACR-2019 SLE classification
# ---
# European Alliance of Associations for Rheumatology (EULAR) - AUTHORED(EULAR developed the 2019 SLE classification) -> EULAR/ACR-2019 SLE classification
# ---
# EULAR/ACR-2019 SLE classification - ASSOCIATED_WITH(EULAR/ACR-2019 classification compared to the ACR-1997 classification criteria) -> ACR-1997 classification criteria
# ---
# EULAR/ACR-2019 SLE classification - INCLUDES(Positive ANA emphasized as an obligatory entry criterion for SLE by EULAR/ACR-2019 classification) -> Positive ANA
# ---
# EULAR/ACR-2019 SLE classification - INCLUDES(EULAR/ACR-2019 lists three immunologic biomarkers) -> immunologic biomarkers
# ---
# EULAR/ACR-2019 SLE classification - INCLUDES(EULAR/ACR-2019 includes seven clinical indices) -> clinical indices
# ---
# SLE diagnosis - DESCRIBES(SLE diagnosis refers to diagnosis of the disease SLE (systemic lupus erythematosus) as used in the text) -> SLE
# ---
# C3 - BIOMARKER_FOR(C3 levels have low specificity for diagnosing SLE) -> SLE diagnosis
# ---
# C4 - BIOMARKER_FOR(C4 levels have low specificity for diagnosing SLE) -> SLE diagnosis
# ---
# either low C3 or low C4 together with a positive ANA test - BIOMARKER_FOR(either low C3 or low C4 together with a positive ANA test showed 94.3% specificity for an SLE diagnosis) -> SLE diagnosis
# ---
# simultaneously low C3 and C4 plus positive ANA - BIOMARKER_FOR(showed 97.6% specificity for an SLE diagnosis) -> SLE diagnosis
# ---
# low C3 - CONTRIBUTES_TO(low C3 contributes to SLE diagnosis (less readily than simultaneous low C3 and C4, as stated)) -> SLE diagnosis
# ---
# low C4 - CONTRIBUTES_TO(low C4 contributes to SLE diagnosis (less readily than simultaneous low C3 and C4, as stated)) -> SLE diagnosis
# ---
# low C3 and low C4 - CONTRIBUTES_TO(patients with low levels of both C3 and C4 are more readily diagnosed with SLE than patients with low C3 or low C4) -> SLE diagnosis
# ---
# null
# ---
# null
# ---
# null
# ---
# null
# ---
# null
# ---
# 6.1. Transcriptome in SLE - DESCRIBES(section relates transcriptome to SLE) -> SLE
# ---
# 6.1. Transcriptome in SLE - DESCRIBES(section title relating transcriptome to SLE) -> transcriptome
# ---
# SLE pathogenesis - DESCRIBES(pathogenesis of SLE) -> SLE
# ---
# SLE pathogenesis - ASSOCIATED_WITH(SLE pathogenesis is the pathogenic process of SLE) -> SLE
# ---
# Epigenetic alterations - CONTRIBUTES_TO(Epigenetic alterations play a key role in SLE pathogenesis) -> SLE pathogenesis
# ---
# dysregulation of gene expression - CONTRIBUTES_TO(dysregulation of gene expression contributes to SLE pathogenesis) -> SLE pathogenesis
# ---
# cells of the immune system - CONTRIBUTES_TO(Several immune cells are thought to be involved in SLE pathogenesis) -> SLE pathogenesis
# ---
# clinical practice guidelines on SLE - DESCRIBES(Clinical practice guidelines are on SLE) -> SLE
# ---
# recent work (framework of ERN ReCONNET) - ASSESSES(Recent work reviewed existing clinical practice guidelines on SLE) -> clinical practice guidelines on SLE
# ---
# SLE Immunobiology - DESCRIBES(Section heading and text describe systemic lupus erythematosus (SLE)) -> SLE
# ---
# SLE Immunobiology - DESCRIBES(Article/section describes scope towards improving precision in lupus care) -> Improving precision in lupus care
# ---
# SLE Immunobiology - INCLUDES(Microbiome aspects are considered in the article/section) -> Microbiome
# ---
# SLE Immunobiology - INCLUDES(Environmental aspects are considered in the article/section) -> Environmental aspects
# ---
# SLE Immunobiology - INCLUDES(The current treatment approach is addressed in the article/section) -> Current treatment approach
# ---
# SLE Immunobiology - INCLUDES(A perspective to evolve precision is envisaged in the article/section) -> Perspective to evolve precision
# ---
# SLE Immunobiology - INCLUDES(Epigenetic aspects are considered in the article/section) -> Epigenetic aspects
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article content relates to SLE) -> SLE
# ---
# Lever et al - AUTHORED(Lever et al authored the article) -> Intestinal Microbiota and SLE
# ---
# Intestinal Microbiota and SLE - ASSOCIATED_WITH(Article appears in the referenced publication/journal listing) -> Pharmacogenomics and Personalized Medicine 2020:13
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Text fragment includes 'cell cycle arrest' described in the document) -> cell cycle arrest
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article topic: intestinal microbiota) -> Intestinal Microbiota
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article content relates to Sjogrens patients) -> Sjogrens
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article discusses differential gut microbiota) -> gut microbiota
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article describes mouse model work) -> mice
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article describes leaky gut phenotype in models) -> gut is leaky
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article describes finding of enterococcus translocation to liver) -> enterococcus
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Article describes liver involvement in translocation finding) -> liver
# ---
# Intestinal Microbiota and SLE - DESCRIBES(Text fragment includes 'through alkylation' described in the document) -> alkylation
# ---
# The Challenge of Moving T owards Precision Medicine in SLE - DESCRIBES(Article concerns SLE (title/context)) -> SLE
# ---
# The Challenge of Moving T owards Precision Medicine in SLE - DESCRIBES(Article describes pathophysiological aspects of SLE) -> pathophysiological aspects of SLE
# ---
# The Challenge of Moving T owards Precision Medicine in SLE - DESCRIBES(Article discusses Precision Medicine (title/context)) -> Precision Medicine
# ---
# The Challenge of Moving T owards Precision Medicine in SLE - DESCRIBES(Article mentions disease control and patient outcomes) -> control and patient outcomes
# ---
# The Challenge of Moving T owards Precision Medicine in SLE - INCLUDES(Article references Table 2) -> Table 2 Treatment Based on the Organ/Systemic Involved
# ---
# SLE - INCLUDES(SLE includes patients described as 'SLE patients' in the text) -> SLE patients
# ---
# SLE patients - ASSOCIATED_WITH(group of patients with SLE) -> SLE
# ---
# SLE patients - ASSOCIATED_WITH(The group 'SLE patients' refers to patients with SLE) -> SLE (systemic lupus erythematosus)
# ---
# SLE patients - ASSOCIATED_WITH(In SLE patients the DC population has well-established abnormalities) -> DC population abnormalities
# ---
# SLE patients - ASSOCIATED_WITH(CR2 receptor expression is lower in SLE patients) -> lower CR2 expression
# ---
# high sensitivity - ASSOCIATED_WITH(high sensitivity value observed in SLE patients) -> SLE patients
# ---
# ANuA - ASSOCIATED_WITH(Presence of ANuA is related to findings in SLE patients) -> SLE patients
# ---
# serum cardiac troponin T (high sensitivity) - ASSOCIATED_WITH(text: troponin T association described in SLE patients) -> SLE patients
# ---
# publicly available multi-omics data - ASSOCIATED_WITH(data from SLE patients) -> SLE patients
# ---
# Microparticles - ASSOCIATED_WITH(differences in microparticles have been noticed compared to SLE patients) -> SLE patients
# ---
# Neutrophils - ASSOCIATED_WITH(These cells, in SLE patients, were studied and shown to have defects) -> SLE patients
# ---
# SLE patients - INCLUDES(SLE patients includes subset 'SLE patients with CVD' (text: 'SLE patients with CVD')) -> SLE patients with CVD
# ---
# SLE patients - INCLUDES(SLE patients have an abnormal subset of neutrophils) -> neutrophils
# ---
# SLE patients - INCLUDES(SLE patients include T cells in SLE patients) -> T cells in SLE patients
# ---
# patients - INCLUDES(patients includes SLE patients as a subset) -> SLE patients
# ---
# focus group on communication gap - INCLUDES(focus group was among SLE patients) -> SLE patients
# ---
# SLE patients - HAS_SYMPTOM(SLE patients have increased susceptibility to infection (in these patients)) -> increased susceptibility to infection
# ---
# SLE patients - HAS_SYMPTOM(SLE patients have an abnormal subset) -> abnormal subset
# ---
# assessment of SLE patients - ASSESSES(Assessment is performed on SLE patients) -> SLE patients
# ---
# Precision medicine - ASSESSES(Precision medicine addresses the need to assess SLE patients optimally) -> SLE patients
# ---
# therapeutic targets - USED_FOR(text: 'useful therapeutic targets for SLE' (therapeutic targets used in context of SLE patients)) -> SLE patients
# ---
# PROs (patient-reported outcomes) - USED_FOR(could provide SLE patients with an opportunity to actively participate in their treatment (text excerpt)) -> SLE patients
# ---
# belimumab - TREATS(effective way to treat SLE patients) -> SLE patients
# ---
# rituximab - TREATS(effective way to treat SLE patients) -> SLE patients
# ---
# improvement of prognosis - AFFECTS(improvement of prognosis of SLE patients) -> SLE patients
# ---
# SLE - INCLUDES(SLE includes patients with SLE screened in clinical trials for new therapies (text context)) -> patients with SLE screened in clinical trials for new therapies
# ---
# up to 30% ANA-negative in patients with SLE in clinical trials - ASSOCIATED_WITH(up to 30% ANA-negative observed in patients with SLE screened in clinical trials for new therapies) -> patients with SLE screened in clinical trials for new therapies
# ---
# SLE - INCLUDES(SLE can be complicated with renal flares) -> renal flares
# ---
# anti-C1q antibodies - BIOMARKER_FOR(anti-C1q antibodies may serve as a non-invasive biomarker for predicting renal flares) -> renal flares
# ---
# increased anti-C1q antibody titers - BIOMARKER_FOR(increased anti-C1q antibody titers predict renal flares in LN) -> renal flares
# ---
# SLE - INCLUDES(SLE can be complicated with hematologic flares) -> hematologic flares
# ---
# SLE - INCLUDES(NPSLE is a neuropsychiatric manifestation of SLE) -> NPSLE
# ---
# IP-10 - ASSOCIATED_WITH(IP-10 associated with NPSLE; reported in CSF. [78,79]) -> NPSLE
# ---
# MCP-1 - ASSOCIATED_WITH(MCP-1 associated with NPSLE; reported in CSF. [78,79]) -> NPSLE
# ---
# IL-8 - ASSOCIATED_WITH(IL-8 associated with NPSLE) -> NPSLE
# ---
# IL-6 - ASSOCIATED_WITH(IL-6 associated with NPSLE) -> NPSLE
# ---
# Anti-RibP - ASSOCIATED_WITH(Anti-RibP associated with NPSLE) -> NPSLE
# ---
# Anti-U1 ribonucleoprotein antibodies - ASSOCIATED_WITH(Anti-U1 RNP antibodies elevated in NPSLE patients) -> NPSLE
# ---
# IL-10 - ASSOCIATED_WITH(IL-10 associated with NPSLE) -> NPSLE
# ---
# TNF-alpha - ASSOCIATED_WITH(TNF-alpha associated with NPSLE) -> NPSLE
# ---
# IFN-γ - ASSOCIATED_WITH(IFN-γ associated with NPSLE; reported in CSF. [78,79]) -> NPSLE
# ---
# Anti-ribosomal P protein antibodies - ASSOCIATED_WITH(Anti-ribosomal P protein antibodies have been found to relate to NPSLE in some reports) -> NPSLE
# ---
# cellular-induced inflammation - DESCRIBES(Text states 'Cellular-induced inflammation might also contribute' (no explicit target specified)) -> NPSLE
# ---
# Anti-U1 ribonucleoprotein antibodies - CONTRIBUTES_TO(Anti-U1 RNP antibodies might cause NPSLE) -> NPSLE
# ---
# SLE - INCLUDES(SLE manifestations can be divided into type 1 category) -> Type 1 manifestations
# ---
# Type 1 manifestations - ASSOCIATED_WITH(Type 1 manifestations are typically assessed in measures of disease activity) -> disease activity
# ---
# Type 1 manifestations - ASSOCIATED_WITH(Type 1 manifestations are clearly correlated to proinflammatory mechanisms) -> proinflammatory mechanisms
# ---
# Type 1 manifestations - INCLUDES(nephritis given as example of type 1 manifestations) -> nephritis
# ---
# Type 1 manifestations - INCLUDES(arthritis given as example of type 1 manifestations) -> arthritis
# ---
# Type 1 manifestations - INCLUDES(vasculitis given as example of type 1 manifestations) -> vasculitis
# ---
# SLE - INCLUDES(SLE manifestations can be divided into type 2 category) -> Type 2 manifestations
# ---
# Type 2 manifestations - INCLUDES(fatigue listed as an example of type 2 manifestations) -> fatigue
# ---
# Type 2 manifestations - INCLUDES(widespread body pain listed as an example of type 2 manifestations) -> widespread body pain
# ---
# Type 2 manifestations - INCLUDES(depression listed as an example of type 2 manifestations) -> depression
# ---
# Type 2 manifestations - INCLUDES(anxiety listed as an example of type 2 manifestations) -> anxiety
# ---
# Type 2 manifestations - INCLUDES(cognitive listed as an example of type 2 manifestations) -> cognitive
# ---
# SLE - INCLUDES(disease has activity features which are identified clinically) -> activity features
# ---
# physician - ASSESSES(physician identifies the activity features clinically) -> activity features
# ---
# SLE - HAS_SYMPTOM(SLE is diagnosed and classified based on a patient's clinical symptoms) -> clinical symptoms
# ---
# patient - HAS_SYMPTOM(a patient presents clinical symptoms) -> clinical symptoms
# ---
# clinical symptoms - ASSESSES(clinical symptoms are used to diagnose and classify SLE) -> SLE
# ---
# SLE - HAS_SYMPTOM(SLE is diagnosed and classified based on signs) -> signs
# ---
# patient - HAS_SYMPTOM(a patient presents signs) -> signs
# ---
# signs - ASSESSES(signs are used to diagnose and classify SLE) -> SLE
# ---
# SLE - HAS_SYMPTOM(presents with renal symptoms) -> renal symptoms
# ---
# SLE - HAS_SYMPTOM(SLE exhibits dermatological symptoms) -> dermatological symptoms
# ---
# SLE - HAS_SYMPTOM(presents with neuropsychiatric symptoms) -> neuropsychiatric symptoms
# ---
# SLE - HAS_SYMPTOM(presents with cardiovascular symptoms) -> cardiovascular symptoms
# ---
# SLE - HAS_SYMPTOM(skin lesions occur in SLE (mentioned as skin lesions in SLE)) -> skin lesions
# ---
# AhR ratio (ratio of AhR in Th17 to Treg) - CONTRIBUTES_TO(AhR ratio may be an independent risk factor for skin lesions) -> skin lesions
# ---
# ratio - CONTRIBUTES_TO(ratio may be an independent risk factor for skin lesions in SLE [68]) -> skin lesions
# ---
# biomarkers - USED_FOR(only a few biomarkers can be used for skin lesions) -> skin lesions
# ---
# SLE - HAS_SYMPTOM(SLE has symptoms) -> symptoms
# ---
# symptoms - ASSOCIATED_WITH(many symptoms can be potential expressions of 'lupus being back') -> lupus being back
# ---
# lupus patients - ASSOCIATED_WITH(for lupus patients, many symptoms are observed) -> symptoms
# ---
# ability to describe symptoms - ASSOCIATED_WITH(Ability to describe is related to the patient's symptoms.) -> symptoms
# ---
# lupus - INCLUDES(Lupus has many different expressions.) -> symptoms
# ---
# lupus - HAS_SYMPTOM(Many symptoms can be potential expressions of lupus.) -> symptoms
# ---
# tracking symptoms over longer periods - ASSESSES(tracking over longer periods assesses symptoms) -> symptoms
# ---
# learning with doctors what symptoms matter for them - ASSESSES(learning with doctors assesses which symptoms matter for the patient) -> symptoms
# ---
# medication - TREATS(medication can control the symptoms) -> symptoms
# ---
# multidisciplinary approach - TREATS(multidisciplinary approach can control the symptoms) -> symptoms
# ---
# approach for treating SLE - RESULTS_IN(approach for treating SLE can control the symptoms) -> symptoms
# ---
# SLE - HAS_SYMPTOM(severe manifestations are manifestations of SLE) -> severe manifestations of SLE
# ---
# low-frequency risk alleles of ITGAM - ASSOCIATED_WITH(alleles relate to severe manifestations of SLE) -> severe manifestations of SLE
# ---
# risk factors - ASSOCIATED_WITH(risk factors relate to severe manifestations of SLE) -> severe manifestations of SLE
# ---
# SLE - HAS_SYMPTOM(Disease severity is an outcome associated with SLE) -> disease severity
# ---
# defective production of reactive oxygen species (ROS) - ASSOCIATED_WITH(ROS production was correlated with disease severity) -> disease severity
# ---
# null
# ---
# disease severity - RESULTS_IN() -> benefit from B-cell depletion
# ---
# SLE - HAS_SYMPTOM(Organ damage is an outcome associated with SLE) -> organ damage
# ---
# organ damage - ASSOCIATED_WITH(organ damage is not strongly associated with measures of QoL) -> quality of life (QoL) measures
# ---
# defective production of reactive oxygen species (ROS) - ASSOCIATED_WITH(ROS production was correlated with organ damage) -> organ damage
# ---
# Systemic lupus erythematosus (SLE) - INCLUDES(organ damage is a feature of SLE) -> organ damage
# ---
# organ damage - CONTRIBUTES_TO(prognosis depends mainly on organ damage) -> unpredictable prognosis
# ---
# laboratory biomarkers - ASSESSES(laboratory biomarkers are used to diagnose and classify SLE) -> SLE
# ---
# laboratory biomarkers - ASSOCIATED_WITH(laboratory biomarkers reflect immune reactivity) -> immune reactivity
# ---
# laboratory biomarkers - ASSOCIATED_WITH(laboratory biomarkers reflect inflammation) -> inflammation
# ---
# Figure 1. Common biomarkers for SLE - DESCRIBES(Figure 1 shows common biomarkers) -> laboratory biomarkers
# ---
# Biomolecules 2021, 11, 928 (article) - DESCRIBES(article text contains list of laboratory biomarkers) -> laboratory biomarkers
# ---
# laboratory biomarkers - INCLUDES(listed biomarker) -> proteinuria
# ---
# laboratory biomarkers - INCLUDES(listed biomarker) -> urinary casts
# ---
# laboratory biomarkers - INCLUDES(listed biomarker) -> hemolytic anemia with reticulocytosis
# ---
# laboratory biomarkers - INCLUDES(listed laboratory parameter) -> white blood cells
# ---
# laboratory biomarkers - INCLUDES(listed laboratory parameter) -> lymphocytes
# ---
# laboratory biomarkers - INCLUDES(listed laboratory parameter) -> platelets
# ---
# laboratory biomarkers - INCLUDES(listed antibody biomarker) -> Smith (Sm) antibody
# ---
# laboratory biomarkers - INCLUDES(listed antibody biomarker) -> antinuclear antibody (ANA)
# ---
# laboratory biomarkers - INCLUDES(listed antibody biomarker) -> DNA antibody
# ---
# laboratory biomarkers - INCLUDES(listed laboratory parameter) -> total complement activity
# ---
# laboratory biomarkers - INCLUDES(listed complement component) -> complement 2 (C2)
# ---
# laboratory biomarkers - INCLUDES(listed complement component) -> complement 3 (C3)
# ---
# laboratory biomarkers - INCLUDES(listed complement component) -> complement 4 (C4)
# ---
# laboratory biomarkers - INCLUDES(listed laboratory finding) -> lupus erythematosus (LE) cells
# ---
# ACR classification criteria (revised 1997) - INCLUDES(classification criteria contain laboratory biomarkers) -> laboratory biomarkers
# ---
# immunoassay - ASSESSES(immunoassay with demonstrated ≥ 90% specificity assesses SLE against relevant disease controls) -> SLE
# ---
# immunoassay - ASSOCIATED_WITH(specificity demonstrated against relevant disease controls) -> relevant disease controls
# ---
# ANA test - ASSESSES(ANA test used to assess SLE; a negative ANA test cannot rule out SLE diagnosis (text statement)) -> SLE
# ---
# ANA test - RESULTS_IN(ANA test can result in a negative (ANA-negative) result) -> ANA-negative
# ---
# ANuA assay - ASSESSES(Sensitivity and specificity of the ANuA assay for SLE) -> SLE
# ---
# mathematical models - ASSESSES(mathematical models may be used to assess SLE) -> SLE
# ---
# mathematical models - INCLUDES(multiple biomarkers combined through mathematical models) -> multiple biomarkers
# ---
# BILAG - ASSESSES(BILAG scores assess SLE disease activity) -> SLE
# ---
# BILAG - ASSOCIATED_WITH(BILAG C scores / Single B associated with Mild Disease) -> Mild Disease
# ---
# BILAG - ASSOCIATED_WITH(2 or more BILAG Bs associated with Moderate Disease) -> Moderate Disease
# ---
# BILAG - ASSOCIATED_WITH(1 or more BILAG A associated with Severe Disease) -> Severe Disease
# ---
# SLEDAI - ASSESSES(SLEDAI assesses SLE disease activity) -> SLE
# ---
# SLEDAI - ASSOCIATED_WITH(SLEDAI ≤6 associated with Mild Disease) -> Mild Disease
# ---
# SLEDAI - ASSOCIATED_WITH(SLEDAI 6-12 associated with Moderate Disease) -> Moderate Disease
# ---
# SLEDAI - ASSOCIATED_WITH(SLEDAI ≥12 associated with Severe Disease) -> Severe Disease
# ---
# 1 or more BILAG A or SLEDAI 6 12 - INCLUDES(criterion includes SLEDAI (threshold 6 12)) -> SLEDAI
# ---
# SLE - CONTRIBUTES_TO(SLE in terms of damage accrual) -> damage accrual
# ---
# cytokine production - CONTRIBUTES_TO(cytokine production has a central role in SLE) -> SLE
# ---
# cytokine production - CONTRIBUTES_TO(cytokine production contributes to exacerbation of LN) -> active LN
# ---
# B cells - CONTRIBUTES_TO(B cells responsible for cytokine production) -> cytokine production
# ---
# anti-dsDNA antibodies - ACTIVATES(anti-dsDNA antibodies can drive cytokine production) -> cytokine production
# ---
# metabolome - CONTRIBUTES_TO(metabolome plays a key role in SLE) -> SLE
# ---
# mass-spectrometry-based metabolic developments - AFFECTS(developments in mass-spectrometry-based metabolic approaches relate to considering the metabolome key in SLE) -> metabolome
# ---
# defective production of reactive oxygen species (ROS) - CONTRIBUTES_TO(Defective production of ROS may contribute to SLE) -> SLE
# ---
# one study - DESCRIBES(One study correlated ROS production with disease severity and organ damage) -> defective production of reactive oxygen species (ROS)
# ---
# defective production of reactive oxygen species (ROS) - PRODUCES(Refers to production (defective) of reactive oxygen species (ROS)) -> reactive oxygen species (ROS)
# ---
# antibody production - CONTRIBUTES_TO(antibody production has a central role in SLE) -> SLE
# ---
# B cells - CONTRIBUTES_TO(B cells responsible for antibody production) -> antibody production
# ---
# antigens - CONTRIBUTES_TO(antigens may result in antibody production) -> antibody production
# ---
# loss of self-tolerance - CONTRIBUTES_TO(central to SLE pathophysiology) -> SLE
# ---
# loss of self-tolerance - ASSOCIATED_WITH(loss of self-tolerance may occur in the thymus) -> thymus
# ---
# loss of self-tolerance - ASSOCIATED_WITH(loss of self-tolerance may occur peripherally) -> periphery
# ---
# loss of self-tolerance - CONTRIBUTES_TO(Loss of self-tolerance contributes to auto-immune diseases) -> auto-immune diseases
# ---
# loss of self-tolerance - CONTRIBUTES_TO(loss of self-tolerance is pivotal in all auto-immune diseases) -> auto-immune diseases
# ---
# loss of self-tolerance - AFFECTS(Loss of self-tolerance affects T cells) -> T cells
# ---
# loss of self-tolerance - AFFECTS(Loss of self-tolerance affects B cells) -> B cells
# ---
# T cells - CAUSES(loss of self-tolerance by T cells) -> loss of self-tolerance
# ---
# dysfunction of antigen presentation - CAUSES(Malfunction of antigen presentation may cause loss of self-tolerance) -> loss of self-tolerance
# ---
# other cells - CONTRIBUTES_TO(other cells have a central role in SLE) -> SLE
# ---
# antibodies - USED_FOR(used as additive weighted criteria for SLE) -> SLE
# ---
# immunological biomarkers - INCLUDES(immunological biomarkers include antibodies) -> antibodies
# ---
# biomarkers used for SLE classification - INCLUDES(biomarkers used for SLE classification include antibodies) -> antibodies
# ---
# complement proteins - USED_FOR(used as additive weighted criteria for SLE) -> SLE
# ---
# immunological biomarkers - INCLUDES(immunological biomarkers include complement proteins) -> complement proteins
# ---
# biomarkers used for SLE classification - INCLUDES(biomarkers used for SLE classification include complement proteins) -> complement proteins
# ---
# SLE-specific antibodies - USED_FOR(used as additive weighted criteria for SLE) -> SLE
# ---
# immunological biomarkers - INCLUDES(immunological biomarkers include SLE-specific antibodies) -> SLE-specific antibodies
# ---
# biomarkers used for SLE classification - INCLUDES(biomarkers used for SLE classification include SLE-specific antibodies) -> SLE-specific antibodies
# ---
# seven clinical indices - USED_FOR(seven clinical indices used as additive weighted criteria for SLE) -> SLE
# ---
# seven clinical indices - INCLUDES(seven clinical indices include constitutional) -> constitutional
# ---
# seven clinical indices - INCLUDES(seven clinical indices include hematologic) -> hematologic
# ---
# seven clinical indices - INCLUDES(seven clinical indices include neuropsychiatric) -> neuropsychiatric
# ---
# seven clinical indices - INCLUDES(seven clinical indices include mucocutaneous) -> mucocutaneous
# ---
# seven clinical indices - INCLUDES(seven clinical indices include serosal) -> serosal
# ---
# seven clinical indices - INCLUDES(seven clinical indices include musculoskeletal) -> musculoskeletal
# ---
# seven clinical indices - INCLUDES(seven clinical indices include renal) -> renal
# ---
# biomarkers used for SLE classification - USED_FOR(biomarkers categorized are used for SLE classification) -> SLE
# ---
# Table 1 - DESCRIBES(Table 1 categorizes the biomarkers used for SLE classification) -> biomarkers used for SLE classification
# ---
# Patient Reported Outcomes (PROs) - USED_FOR(PROs are acquiring an important role in the management of SLE) -> SLE
# ---
# physician-assessed health outcomes - ASSOCIATED_WITH(physician-assessed health outcomes and patient-reported outcomes both capture health status aspects) -> Patient Reported Outcomes (PROs)
# ---
# Patient Reported Outcomes (PROs) - DESCRIBES(PROs are health status evaluations) -> health status evaluations
# ---
# Theoretical usefulness of PROs - DESCRIBES(Theoretical usefulness describes PROs as useful to collect information from patients' perspective) -> Patient Reported Outcomes (PROs)
# ---
# Patient Reported Outcomes (PROs) - INCLUDES(PROs are administered as questionnaires) -> Questionnaires
# ---
# Patient Reported Outcomes (PROs) - CONTRIBUTES_TO(PROs help overcome/reduce the communication gap between patients and clinicians) -> communication gap between patients and clinicians
# ---
# Patient Reported Outcomes (PROs) - CONTRIBUTES_TO(PROs seem to facilitate communication between patients and doctors) -> communication between patients and doctors
# ---
# Patient Reported Outcomes (PROs) - USED_FOR(PROs are used to collect information deriving from the patients' perspective) -> Information deriving from the patients' perspective
# ---
# patients - PRODUCES(PROs are directly reported by the patient without interpretation by a physician or anyone else) -> Patient Reported Outcomes (PROs)
# ---
# treat to target (T2T) - USED_FOR(T2T has been applied in SLE (applied in SLE)) -> SLE
# ---
# Omics - USED_FOR(Omics used to gain insight into SLE) -> SLE
# ---
# Omics - INCLUDES(Omics includes transcriptome) -> transcriptome
# ---
# Omics - INCLUDES(Omics includes epigenome) -> epigenome
# ---
# Omics - INCLUDES(Omics includes genome) -> genome
# ---
# Omics - INCLUDES(Omics includes metabolome) -> metabolome
# ---
# Omics - USED_FOR(Omics used to track the disease course) -> track the disease course
# ---
# T2T approach - USED_FOR(T2T approach has been applied to SLE) -> SLE
# ---
# strategy for the monitoring and treatment of SLE - USED_FOR(strategy relates to monitoring and treatment of SLE) -> SLE
# ---
# strategy for the monitoring and treatment of SLE - INCLUDES(strategy relies on integration of patient-driven data) -> patient-driven data
# ---
# strategy for the monitoring and treatment of SLE - INCLUDES(strategy integrates traditional clinical evaluation) -> traditional clinical evaluation
# ---
# several questionnaires - USED_FOR(several questionnaires have been used to date for SLE) -> SLE
# ---
# SLE Treatment Based on Severity of the Disease - USED_FOR(Table describes treatment based on SLE severity) -> SLE
# ---
# SLE Treatment Based on Severity of the Disease - INCLUDES(treatment includes hydroxychloroquine) -> hydroxychloroquine
# ---
# SLE Treatment Based on Severity of the Disease - INCLUDES(treatment includes topical steroids) -> topical steroids
# ---
# SLE Treatment Based on Severity of the Disease - INCLUDES(treatment includes oral steroids) -> oral steroids
# ---
# medication - TREATS(medication for treating SLE) -> SLE
# ---
# doctor - ASSOCIATED_WITH(doctor focus on medication) -> medication
# ---
# questions on medication - ASSOCIATED_WITH(questions relate to medication) -> medication
# ---
# medication - CONTRIBUTES_TO(medication can delay progression of the disease) -> progression of the disease
# ---
# multidisciplinary approach - TREATS(multidisciplinary approach for treating SLE) -> SLE
# ---
# multidisciplinary approach - CONTRIBUTES_TO(multidisciplinary approach can delay progression of the disease) -> progression of the disease
# ---
# hydroxychloroquine - TREATS(hydroxychloroquine is given in treatment of SLE) -> SLE
# ---
# management of SLE - INCLUDES(management outline indicates inclusion of hydroxychloroquine) -> hydroxychloroquine
# ---
# non-aggressive treatment - INCLUDES(non-aggressive treatment includes hydroxychloroquine) -> hydroxychloroquine
# ---
# patients with SLE - RECEIVED(Most patients are given hydroxychloroquine) -> hydroxychloroquine
# ---
# hydroxychloroquine - TREATS(hydroxychloroquine is used to treat many of the (SLE manifestations)) -> Systemic lupus erythematosus (SLE)
# ---
# hydroxychloroquine - TREATS(Most patients are given hydroxychloroquine (treatment for lupus)) -> lupus
# ---
# hydroxychloroquine - PRESCRIBED(hydroxychloroquine is prescribed to most patients) -> patients with lupus
# ---
# hydroxychloroquine - PRESCRIBED(hydroxychloroquine may be included in treatment for mild disease) -> mild disease
# ---
# physician - TREATS(physician identifies activity features clinically and applies appropriate management) -> SLE
# ---
# physician - ASSOCIATED_WITH(Physician is the source of the physician's point of view) -> physician's point of view
# ---
# trust in the physician - ASSOCIATED_WITH(Trust in the physician is associated with the physician) -> physician
# ---
# physician - DESCRIBES(from the physician's point of view, it remains difficult to translate the results of PROs into a treatment strategy (text excerpt)) -> difficulty translating PROs results into a treatment strategy
# ---
# care process - INCLUDES(Care process includes the physician's point of view) -> physician
# ---
# physician - ASSESSES(physician assesses physician-assessed health outcomes) -> physician-assessed health outcomes
# ---
# new strategy for the monitoring and treatment of SLE - TREATS(strategy is for the monitoring and treatment of SLE) -> SLE
# ---
# new strategy for the monitoring and treatment of SLE - ASSOCIATED_WITH(relies on the integration of patient-driven data) -> patient-driven data
# ---
# patients - CONTRIBUTES_TO(patients worked side by side in the development of the new strategy) -> new strategy for the monitoring and treatment of SLE
# ---
# clinicians - CONTRIBUTES_TO(clinicians worked side by side in the development of the new strategy) -> new strategy for the monitoring and treatment of SLE
# ---
# prednisolone - TREATS(prednisolone is given in treatment of SLE) -> SLE
# ---
# management of SLE - INCLUDES(management outline indicates inclusion of prednisolone) -> prednisolone
# ---
# patients with SLE - RECEIVED(Most patients are given prednisolone) -> prednisolone
# ---
# immunosuppressives - TREATS(immunosuppressives accompany treatment of SLE) -> SLE
# ---
# management of SLE - INCLUDES(management outline indicates inclusion of immunosuppressives) -> immunosuppressives
# ---
# patients with SLE - RECEIVED(prednisolone and hydroxychloroquine are accompanied by immunosuppressives) -> immunosuppressives
# ---
# appropriate management - TREATS(appropriate management for the disease (applied by physician)) -> SLE
# ---
# Rituximab - TREATS(permitted for use in the disease (as noted by NHS England)) -> SLE
# ---
# Rituximab - ASSOCIATED_WITH(Rituximab use is increasing) -> increasing use
# ---
# American College of Rheumatology - ASSOCIATED_WITH(American College of Rheumatology recommend its use in renal lupus (text, ref83)) -> Rituximab
# ---
# 2nd Line - ASSOCIATED_WITH(2nd Line 'ADD Rituximab' (text)) -> Rituximab
# ---
# NHS England - ASSOCIATED_WITH(permits the use of Rituximab in the UK (text)) -> Rituximab
# ---
# European League Against Rheumatism - ASSOCIATED_WITH(European League Against Rheumatism recommend its use in renal lupus (text, ref84)) -> Rituximab
# ---
# 2nd Line - INCLUDES(listed under 2nd Line (Rituximab)) -> Rituximab
# ---
# 3rd Line - INCLUDES(listed under 3rd Line (Rituximab)) -> Rituximab
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> Rituximab
# ---
# Unpublished observations - ASSESSES(unpublished observations assess Rituximab's effects; observe quick correction of haematological problems but slower benefit for renal disease (text)) -> Rituximab
# ---
# Rituximab - USED_FOR(Rituximab recommended for use in renal lupus (text)) -> renal lupus
# ---
# Rituximab - TREATS(often works quickly to correct thrombocytopenia (unpublished observations)) -> thrombocytopenia
# ---
# Rituximab - TREATS(often works quickly to correct haemolytic anaemia (unpublished observations)) -> haemolytic anaemia
# ---
# IV Cyclo - RESULTS_IN(IV Cyclo → ... or Rituximab (alternative described in text)) -> Rituximab
# ---
# Rituximab - AFFECTS(Rituximab is much slower to benefit renal disease (observed in unpublished observations)) -> renal disease
# ---
# Rituximab - CAUSES() -> B-cell depletion
# ---
# Benlysta - TREATS(Benlysta is approved for SLE) -> SLE
# ---
# Benlysta - ASSOCIATED_WITH(remains the only biologic allowed in the disease in the USA) -> SLE
# ---
# Federal Drug Administration - ASSOCIATED_WITH(approved Benlysta for SLE in 2012) -> Benlysta
# ---
# Benlysta - DESCRIBES(Benlysta (listed) = Belimumab (listed) as related names in table) -> Belimumab
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> Benlysta
# ---
# Benlysta - INTERACTS_WITH(Benlysta is anti-BAFF) -> BAFF
# ---
# SLE - RESULTS_IN(healthcare-related costs are costs of SLE) -> healthcare-related costs of SLE
# ---
# healthcare-related costs of SLE - ASSOCIATED_WITH(healthcare-related costs are related to disease severity [5]) -> disease severity
# ---
# healthcare-related costs of SLE - ASSOCIATED_WITH(healthcare-related costs are related to types of organ(s) involved [5]) -> types of organ(s) involved
# ---
# SLE - RESULTS_IN(SLE progression is a disease process) -> progression of the disease
# ---
# approach for treating SLE - RESULTS_IN(approach for treating SLE can delay the progression of the disease) -> progression of the disease
# ---
# SLE - AFFECTS(SLE's complexity and heterogeneity require consideration of multiple aspects in management) -> management of the disease
# ---
# treat to target (T2T) principle - ASSOCIATED_WITH(T2T principle is mentioned in the context of disease management) -> management of the disease
# ---
# two different perspectives - ASSOCIATED_WITH(the two different perspectives relate to management of the disease) -> management of the disease
# ---
# management of the disease - INCLUDES(management includes controlling disease activity) -> controlling disease activity
# ---
# management of the disease - INCLUDES(management includes preventing damage accrual) -> preventing damage accrual
# ---
# management of the disease - INCLUDES(management includes minimizing treatment-related toxicities) -> minimizing treatment-related toxicities
# ---
# management of the disease - INCLUDES(management includes improving patients' quality of life (QoL)) -> improving patients' quality of life (QoL)
# ---
# complexity - CONTRIBUTES_TO(complexity necessitates multiple considerations in disease management) -> management of the disease
# ---
# heterogeneity - CONTRIBUTES_TO(heterogeneity necessitates multiple considerations in disease management) -> management of the disease
# ---
# approach for treating SLE - AFFECTS(approach for treating SLE cannot cure SLE completely) -> SLE
# ---
# Patient with SLE - EXPRESSES(patient with SLE) -> SLE
# ---
# Holistic view of the patient - ASSOCIATED_WITH(holistic view refers to the patient with SLE) -> Patient with SLE
# ---
# Difficulty collecting information from patients - ASSOCIATED_WITH(difficulty collecting information derives from patients (context: patients with SLE)) -> Patient with SLE
# ---
# SLE - CAUSES(can cause damage to various organs) -> damage to various organs
# ---
# damage to various organs - AFFECTS(damage affects various organs) -> various organs
# ---
# SLE - CAUSES(SLE can cause multiple organ damage) -> multiple organ damage
# ---
# SLE - CAUSES(CVD is a complication of SLE) -> Cardiovascular disease (CVD)
# ---
# Cardiovascular involvement in SLE - ASSOCIATED_WITH(cardiovascular involvement in SLE refers to cardiovascular disease (CVD)) -> Cardiovascular disease (CVD)
# ---
# Cardiovascular disease (CVD) - CONTRIBUTES_TO(important factor causing morbidity and mortality) -> morbidity and mortality
# ---
# SLE - ASSOCIATED_WITH(has a complex pathogenesis) -> complex pathogenesis
# ---
# SLE - ASSOCIATED_WITH(SLE displays heterogeneous clinical manifestations) -> heterogeneous clinical manifestations
# ---
# SLE - ASSOCIATED_WITH(SLE diagnosis and classification involves laboratory biomarkers) -> laboratory biomarkers
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include proteinuria) -> proteinuria
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include urinary casts) -> urinary casts
# ---
# classification criteria for SLE - INCLUDES(classification criteria contains laboratory biomarkers) -> laboratory biomarkers
# ---
# laboratory biomarkers - ASSESSES(laboratory biomarkers reflect immune reactivity) -> immune reactivity
# ---
# laboratory biomarkers - ASSESSES(laboratory biomarkers reflect inflammation) -> inflammation
# ---
# SLE - ASSOCIATED_WITH(SLE is correlated with a poor prognosis of LN) -> LN
# ---
# LN - ASSOCIATED_WITH(LN used in text in the same context as renal lupus) -> renal lupus
# ---
# anti-Sm antibodies - ASSOCIATED_WITH(anti-Sm mentioned in context of LN) -> LN
# ---
# psy - ASSOCIATED_WITH(psy has been described as controversial with respect to whether it is required to diagnose LN) -> LN
# ---
# patients with LN - ASSOCIATED_WITH(patients diagnosed with LN) -> LN
# ---
# integrin alpha M (ITGAM) - ASSOCIATED_WITH(confirmed as a susceptibility gene of LN) -> LN
# ---
# poor prognosis of LN - ASSOCIATED_WITH(poor prognosis pertains to LN) -> LN
# ---
# microRNAs - ASSOCIATED_WITH(microRNAs have been implicated in LN context) -> LN
# ---
# low level of a microRNA in LN - ASSOCIATED_WITH(low level of a microRNA occurs in LN) -> LN
# ---
# low level of another microRNA in LN - ASSOCIATED_WITH(low level of another microRNA occurs in LN) -> LN
# ---
# Anti-dsDNA antibodies - BIOMARKER_FOR(Anti-dsDNA antibodies can predict the development of LN) -> LN
# ---
# 24-h urine protein - BIOMARKER_FOR(conventional urinary biomarker for LN) -> LN
# ---
# Angiopoetin-like 4 - BIOMARKER_FOR(Urine biomarker candidate for tracking disease activity in LN) -> LN
# ---
# L-selectin - BIOMARKER_FOR(Urine biomarker candidate for tracking disease activity in LN) -> LN
# ---
# TGF-β1 - BIOMARKER_FOR(Urine biomarker candidate for tracking disease activity in LN) -> LN
# ---
# Proteinuria - BIOMARKER_FOR(conventional urinary biomarker for LN) -> LN
# ---
# protein/creatinine ratio in spot urine - BIOMARKER_FOR(conventional urinary biomarker for LN) -> LN
# ---
# new urinary biomarkers - BIOMARKER_FOR(new urinary biomarkers investigated in context of LN) -> LN
# ---
# urine protein candidate biomarkers - BIOMARKER_FOR(urine protein candidate biomarkers investigated for LN) -> LN
# ---
# peripheral blood neutrophils - BIOMARKER_FOR(peripheral blood neutrophils may not be a robust biomarker for LN) -> LN
# ---
# coronin-1A - BIOMARKER_FOR(coronin-1A identified as a biomarker of LN in kidney tissue proteomics; serum level can distinguish LN from SLE without nephritis) -> LN
# ---
# LN - INCLUDES(LN includes disease activity (i.e., disease activity in LN)) -> disease activity in LN
# ---
# LN - HAS_SYMPTOM(LN is associated with poor prognosis) -> poor prognosis
# ---
# coronin-1A level in serum - ASSESSES(coronin-1A level in serum distinguishes LN patients from SLE patients without nephritis) -> LN
# ---
# decreased C1q - CONTRIBUTES_TO(decreased C1q may play a pathogenic role in the development of LN) -> LN
# ---
# peripheral blood neutrophils - CONTRIBUTES_TO(identified as a risk factor for LN) -> LN
# ---
# SLE - ASSOCIATED_WITH(SLE patients have CVD risk (context from table entries)) -> CVD
# ---
# IgG-anticardiolipin antibodies - ASSOCIATED_WITH(serum levels associated with CVD) -> CVD
# ---
# E-selectin - ASSOCIATED_WITH(serum levels associated with CVD) -> CVD
# ---
# LHR - BIOMARKER_FOR(LHR predicts CVD risk in SLE patients, even at the onset of disease; sample_type: Serum. [80]) -> CVD
# ---
# MHR - BIOMARKER_FOR(MHR predicts CVD risk in SLE patients, even at the onset of disease; sample_type: Serum. [80]) -> CVD
# ---
# therapeutic targets - USED_FOR(preventing CVD) -> CVD
# ---
# SLE - ASSOCIATED_WITH(SLE is complex) -> complexity
# ---
# SLE - ASSOCIATED_WITH(SLE is heterogeneous) -> heterogeneity
# ---
# SLE - ASSOCIATED_WITH(SLE is not a single-target disease) -> single-target disease
# ---
# SLE - ASSOCIATED_WITH(disease characterized by aberrant activity of the immune system) -> aberrant activity of the immune system
# ---
# aberrant activity of the immune system - ASSOCIATED_WITH(aberrant activity pertains to the immune system) -> immune system
# ---
# Systemic lupus erythematosus - ASSOCIATED_WITH(SLE is characterized by aberrant activity of the immune system) -> aberrant activity of the immune system
# ---
# aberrant activity of the immune system - AFFECTS(aberrant activity involves the immune system) -> immune system
# ---
# SLE - ASSOCIATED_WITH(incidence of SLE is 0.3–31.5 in 100,000 per year) -> incidence of SLE
# ---
# SLE - ASSOCIATED_WITH(adjusted prevalence is approaching or exceeding 50–100 in 100,000) -> adjusted prevalence of SLE
# ---
# SLE - ASSOCIATED_WITH(there appears to be a trend of increasing SLE prevalence with time) -> trend of increasing SLE prevalence with time
# ---
# SLE - ASSOCIATED_WITH(healthcare-related costs of SLE are related to disease) -> healthcare-related costs of SLE
# ---
# SLE - ASSOCIATED_WITH(SLE prevalence increasing with time [4]) -> increasing SLE prevalence with time
# ---
# SLE - ASSOCIATED_WITH(SLE is an important social and public health problem) -> social and public health problem
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with fatigue as a symptom) -> Fatigue
# ---
# treatment goals (patient's point of view) - INCLUDES(From the patient's point of view, treatment goals include fatigue) -> Fatigue
# ---
# Symptoms - INCLUDES(Symptoms include fatigue (example)) -> Fatigue
# ---
# Features - INCLUDES(feature list includes fatigue) -> Fatigue
# ---
# Patients with SLE - HAS_SYMPTOM(Fatigue represents one of the most pervasive and bothersome symptoms for patients with SLE) -> Fatigue
# ---
# Fatigue - AFFECTS(Fatigue influences patient perception of disease status) -> patient perception of disease status
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with chronic pain as a symptom) -> Chronic pain
# ---
# treatment goals (patient's point of view) - INCLUDES(From the patient's point of view, treatment goals include chronic pain) -> Chronic pain
# ---
# Patients with SLE - HAS_SYMPTOM(Chronic pain represents one of the most pervasive and bothersome symptoms for patients with SLE) -> Chronic pain
# ---
# Chronic pain - AFFECTS(Chronic pain influences patient perception of disease status) -> patient perception of disease status
# ---
# SLE - ASSOCIATED_WITH(SLE is described as a complex disease) -> Complex disease (descriptor)
# ---
# SLE - ASSOCIATED_WITH(SLE's precise pathophysiology remains uncertain) -> Precise pathophysiology remains uncertain
# ---
# SLE - ASSOCIATED_WITH(discovery of innate immune system participation in SLE knowledge) -> innate immune system
# ---
# innate immune system - INCLUDES(Some immune cells (including DC) belong to the innate immune system) -> Dendritic cells (DC)
# ---
# SLE - ASSOCIATED_WITH(extensive associations with vitamin D) -> vitamin D
# ---
# SLE - ASSOCIATED_WITH(correlating serum levels of vitamin D) -> vitamin D serum levels
# ---
# SLE - ASSOCIATED_WITH(associations with vitamin D-receptor genomic binding sites) -> vitamin D-receptor genomic binding sites
# ---
# SLE - ASSOCIATED_WITH(Text: SLE patients have differential gut microbiota) -> gut microbiota
# ---
# gut microbiota - ASSOCIATED_WITH(Text implies gut microbiota and intestinal microbiota are related/differential) -> Intestinal Microbiota
# ---
# Sjogrens - ASSOCIATED_WITH(Text: Sjogrens patients have differential gut microbiota) -> gut microbiota
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with the stated pathophysiological aspects) -> pathophysiological aspects of SLE
# ---
# pathophysiological aspects of SLE - CONTRIBUTES_TO(Pathophysiological aspects lead to kidney involvement) -> kidney
# ---
# pathophysiological aspects of SLE - CONTRIBUTES_TO(Pathophysiological aspects lead to skin involvement) -> skin
# ---
# pathophysiological aspects of SLE - CONTRIBUTES_TO(Pathophysiological aspects lead to renal disease) -> renal disease
# ---
# diagnosis of SLE - ASSOCIATED_WITH(diagnosis of SLE is associated with SLE) -> SLE
# ---
# ...
# ---
# Process of deciding a strategy - INCLUDES(process of deciding a strategy should include the burden of lupus) -> Burden of lupus
# ---
# this review - DESCRIBES(The review outlines pathological processes in lupus) -> pathological processes in lupus
# ---
# pathological processes in lupus - INCLUDES(Pathological processes include neuropsychiatric involvement) -> neuropsychiatric involvement
# ---
# pathological processes in lupus - INCLUDES(Pathological processes include renal involvement) -> renal involvement
# ---
# this review - DESCRIBES(The review considers epigenetic aspects) -> epigenetic aspects
# ---
# this review - DESCRIBES(The review considers microbiome aspects) -> microbiome aspects
# ---
# this review - DESCRIBES(The review considers environmental aspects) -> environmental aspects
# ---
# lupus patients - ASSOCIATED_WITH(For lupus patients, the personal relationship built with their doctor is key) -> personal relationship
# ---
# Patient - doctor communication - ASSOCIATED_WITH(remains one of the most important issues highlighted by lupus patients) -> lupus patients
# ---
# most severe form - ASSOCIATED_WITH(the most severe (but still frequent) form in lupus patients) -> lupus patients
# ---
# lupus patients - HAS_SYMPTOM(lupus patients report this experience in severe forms) -> patients feel considered as 'the sum of biologic parameters' with no true consideration for how they feel or function
# ---
# quality of life - AFFECTS(Quality of life pertains to or affects the person with lupus.) -> person with lupus
# ---
# differential methylation - CAUSES(differential methylation causes organ selectivity in lupus) -> organ selectivity (selective targeting of organ systems)
# ---
# differential methylation - INCLUDES(differential methylation may be de novo methylation) -> de novo methylation
# ---
# differential methylation - INCLUDES(differential methylation may be local at the tissue) -> local (tissue) methylation
# ---
# DNA methylation - INCLUDES(differential methylation is a form of DNA methylation) -> differential methylation
# ---
# architectural changes to chromatin - AFFECTS(architectural changes affect chromatin) -> chromatin
# ---
# Epstein-Barr Virus - ACTIVATES(proliferation of B cells driven by this virus) -> B cell proliferation
# ---
# mice - ASSOCIATED_WITH(Work on mice suggested the gut is leaky) -> gut is leaky
# ---
# SLEDAI - ASSOCIATED_WITH(gastrointestinal disease not captured at all in SLEDAI) -> gastrointestinal disease
# ---
# SLEDAI - ASSOCIATED_WITH(haemolytic anaemia not captured at all in SLEDAI) -> haemolytic anaemia
# ---
# mild disease - ASSOCIATED_WITH(Mild disease is equivalent to SLEDAI <6) -> SLEDAI
# ---
# SLEDAI scoring system - ASSOCIATED_WITH(limited in representation of the features of lupus that are present) -> features of lupus present
# ---
# precision of lupus care - CONTRIBUTES_TO() -> damage
# ---
# precision of lupus care - TREATS(proactively treating the autoimmunity) -> autoimmunity
# ---
# precision of lupus care - AFFECTS() -> potent medication
# ---
# precision of lupus care - AFFECTS() -> side-effects
# ---
# these standard drugs (steroids, immunosuppressives and Hydroxychloroquine) - CONTRIBUTES_TO(text links these standard drugs with improved mortality figures for lupus (implied contribution)) -> 10-year survival: ~90%
# ---
# this article (Conclusions section) - DESCRIBES(the article analysed recent facets of the pathological basis of lupus) -> pathological basis of lupus
# ---
# this article (Conclusions section) - DESCRIBES(the article analysed recent facets of the immunogenetic basis of lupus) -> immunogenetic basis of lupus
# ---
# physicians - ASSOCIATED_WITH(physicians have guidelines to follow) -> guidelines
# ---
# physicians - ASSOCIATED_WITH(from physicians' point of view: identified as main obstacle to the use of PROs) -> lack of time
# ---
# physicians - ASSOCIATED_WITH(some physicians fear looking at the patient's perspective) -> fear of looking at the patient's perspective
# ---
# clinical data - ASSOCIATED_WITH(clinical data represents a clinician/physician viewpoint) -> physicians
# ---
# physicians - DESCRIBES(clinically relevant treatment targets defined from the physicians' perspective) -> clinically relevant treatment targets
# ---
# physicians - DESCRIBES(physicians suggested strategies to optimize use of time during visits) -> strategies to optimize use of time during visits
# ---
# Best Practice & Research Clinical Rheumatology 37 (2023) 101939 - DESCRIBES(article states some physicians fear looking at the patient's perspective) -> physicians
# ---
# physicians - INCLUDES(rheumatologists are a subset of physicians) -> rheumatologists
# ---
# physicians - ASSESSES(physicians assess physician-assessed health outcomes) -> physician-assessed health outcomes
# ---
# physicians - CONTRIBUTES_TO(dominated the development of remission criteria) -> remission criteria
# ---
# physicians - AFFECTS(physicians favor choices in the management of the disease) -> disease management
# ---
# physicians - AFFECTS(physicians bring explanations for not systematically using PROs and not considering their results) -> patient-reported outcomes (PROs)
# ---
# null
# ---
# null
# ---
# null
# ---
# null
# ---
# null
# ---
# null
# ---
# null
# ---
# null
# ---
# predictors of response - INCLUDES() -> renal involvement
# ---
# organ selectivity - CONTRIBUTES_TO(organ selectivity contributes to diverse clinical features) -> diverse clinical features
# ---
# within individuals - CONTRIBUTES_TO("within individuals" conspires to cause the diverse clinical features) -> diverse clinical features
# ---
# network of factors - CAUSES(network of factors conspires to cause the diverse clinical features) -> diverse clinical features
# ---
# assessor - ASSESSES(the assessor needs to define activity accurately) -> disease activity
# ---
# assessor - ASSESSES(The assessor needs to define activity accurately to capture active disease) -> activity
# ---
# BILAG - ASSOCIATED_WITH(BILAG shown to be reliable) -> reliable
# ---
# BILAG - ASSOCIATED_WITH(BILAG shown to be sensitive to change) -> sensitive to change
# ---
# BILAG - ASSESSES(activity is more comprehensively assessed by BILAG) -> activity
# ---
# BILAG - USED_FOR(BILAG allows classification of mild disease) -> mild disease
# ---
# BILAG - USED_FOR(BILAG allows classification of moderate disease) -> moderate disease
# ---
# BILAG - USED_FOR(BILAG allows classification of severe disease) -> severe disease
# ---
# this review - DESCRIBES(The review outlines the current treatment approach) -> treatment approach
# ---
# Belimumab - ASSOCIATED_WITH() -> BILAG centres
# ---
# 3rd Line - INCLUDES(listed under 3rd Line (Belimumab)) -> Belimumab
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> Belimumab
# ---
# Belimumab - USED_FOR() -> skin and joint disease
# ---
# Belimumab - RESULTS_IN(remission of the disease following treatment with Belimumab) -> remission
# ---
# Belimumab - RESULTS_IN(remission of the disease following treatment with Belimumab) -> remission of the disease
# ---
# Belimumab - INTERACTS_WITH(Belimumab is an anti-BAFF monoclonal) -> BAFF
# ---
# Belimumab - INTERACTS_WITH() -> BAFF
# ---
# National Institute of Clinical Excellence (NICE) - PRESCRIBED() -> Belimumab
# ---
# Table 2 - INCLUDES(Table 2 outlines use of cyclophosphamide) -> cyclophosphamide
# ---
# second-line treatments - INCLUDES(cyclophosphamide as a second-line treatment) -> cyclophosphamide
# ---
# cyclophosphamide - RESULTS_IN(cyclophosphamide used to induce remission) -> remission
# ---
# current treatment - ASSOCIATED_WITH(current treatment can be approached in a more precise and systematic fashion) -> precise and systematic treatment approach
# ---
# tips during consultation - ASSOCIATED_WITH(tips during consultation are given in the context of a consultation) -> consultation
# ---
# Excerpt (E. Elefante et al.) - DESCRIBES(Excerpt describes practices within a consultation) -> consultation
# ---
# consultation - INCLUDES(consultation includes these patient expectations) -> expectations (from the visit)
# ---
# consultation - INCLUDES(during consultation, tips include asking the doctor to explain medical terms and treatment) -> asking the doctor to explain medical terms and treatment
# ---
# consultation - INCLUDES(Consultation includes helping the patient sort questions) -> helping the patient to sort through important or less important questions
# ---
# consultation - INCLUDES(Consultation includes confirming patient understanding) -> confirming understanding of what was discussed in the consultation
# ---
# consultation - INCLUDES(Consultation includes touching on sensitive topics in a softer context) -> touching on some of the sensitive topics listed above in a softer context
# ---
# consultation - RESULTS_IN(A consultation results in an outcome) -> outcome
# ---
# consultation - RESULTS_IN(disappointment appears when consultation is finished or at home) -> disappointment
# ---
# consultation - AFFECTS(The consultation as a whole affects the patient through listed actions) -> patient
# ---
# patient–doctor communication gap - AFFECTS(The communication gap creates a shadow on the consultation before the visit.) -> consultation
# ---
# common cold - AFFECTS(A simple cold involves fewer topics to discuss during consultation compared to lupus.) -> consultation
# ---
# biomarkers for NPSLE - BIOMARKER_FOR(biomarkers for NPSLE (diagnostic)) -> Neuropsychiatric SLE (NPSLE)
# ---
# antiphospholipid antibodies - BIOMARKER_FOR(antiphospholipid antibodies are diagnostic biomarkers of NPSLE) -> Neuropsychiatric SLE (NPSLE)
# ---
# Neuropsychiatric SLE (NPSLE) - INCLUDES(NPSLE encompasses a group of central nervous system syndromes) -> central nervous system syndromes
# ---
# Neuropsychiatric SLE (NPSLE) - INCLUDES(NPSLE encompasses a group of peripheral nervous system syndromes) -> peripheral nervous system syndromes
# ---
# Neuropsychiatric SLE (NPSLE) - INCLUDES(NPSLE manifestations include nonspecific common symptom: headaches) -> headaches
# ---
# Neuropsychiatric SLE (NPSLE) - INCLUDES(NPSLE manifestations include nonspecific common symptom: mood disorders) -> mood disorders
# ---
# Neuropsychiatric SLE (NPSLE) - INCLUDES(NPSLE manifestations include nonspecific common symptom: cognitive dysfunctions) -> cognitive dysfunctions
# ---
# Neuropsychiatric SLE (NPSLE) - INCLUDES(NPSLE manifestations include rarer syndromes such as autonomic dysfunction) -> autonomic dysfunction
# ---
# Neuropsychiatric SLE (NPSLE) - INCLUDES(NPSLE includes CNS manifestations) -> CNS manifestations
# ---
# Neuropsychiatric SLE (NPSLE) - AFFECTS(the diagnosis of NPSLE may pose a clinical challenge) -> clinical diagnostic challenge
# ---
# patient's skills in managing the disease - ASSOCIATED_WITH(skills are in managing the disease) -> disease
# ---
# patient's skills in managing the disease - ASSOCIATED_WITH(the skills belong to the patient) -> patient
# ---
# patient's skills in managing the disease - AFFECTS(the patient's own skills in managing the disease will impact patient-doctor communication) -> patient-doctor communication
# ---
# brochures - DESCRIBES(brochures describe disease) -> disease
# ---
# brochures - DESCRIBES(brochures describe drug side effects) -> drug side effects
# ---
# brochures - DESCRIBES(brochures describe lifestyle options) -> lifestyle options
# ---
# educational tools and informative materials - INCLUDES(educational materials include brochures) -> brochures
# ---
# reliable websites - DESCRIBES(websites describe disease) -> disease
# ---
# reliable websites - DESCRIBES(websites describe drug side effects) -> drug side effects
# ---
# reliable websites - DESCRIBES(websites describe lifestyle options) -> lifestyle options
# ---
# educational tools and informative materials - INCLUDES(educational materials include reliable websites) -> reliable websites
# ---
# immunosuppression - TREATS(controls the disease) -> disease
# ---
# immunosuppression - CONTRIBUTES_TO(renders patients susceptible to infection) -> infection
# ---
# immunosuppression - CONTRIBUTES_TO(long-term risk) -> increased cardiovascular risk
# ---
# immunosuppression - AFFECTS() -> disease
# ---
# Patients - ASSOCIATED_WITH() -> immunosuppression
# ---
# MTX - DESCRIBES(MTX = methotrexate (from abbreviation list)) -> methotrexate
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> MTX
# ---
# AZA - RESULTS_IN(text fragment: 'AZA 12 MTX' (present in table)) -> MTX
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> methotrexate
# ---
# Lever et al - AUTHORED(authors of the table/article; note in text: 'based on the authors\u2019 own experience') -> Dovepress Lever et al Pharmacogenomics and Personalized
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> Cyclophosphamide
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> Hydroxychloroquine
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> azathioprine
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> mycophenolate
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> IVIG
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> PE
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table as full phrase 'plasma exchange') -> plasma exchange
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> IV Cyclo
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> AZA
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> CS
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table) -> Corticosteroids
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> HCQ
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> MMF
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> Cyclo
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(listed in table as 'low molecular weight heparin') -> low molecular weight heparin
# ---
# Dovepress Lever et al Pharmacogenomics and Personalized - INCLUDES(abbreviation listed in table) -> LMWH
# ---
# AZA - DESCRIBES(AZA = azathioprine (from abbreviation list)) -> azathioprine
# ---
# IV Cyclo - RESULTS_IN(text fragment: 'IV Cyclo 12 AZA/IV' (present in table)) -> AZA
# ---
# molecular tools - ASSOCIATED_WITH(on their way to the clinic) -> clinic
# ---
# biologic/small molecule drugs - INCLUDES(listed as part of the five approved therapies for rheumatoid arthritis) -> anti-TNF
# ---
# anti-TNF - INTERACTS_WITH(anti-TNF targets TNF) -> TNF
# ---
# biologic/small molecule drugs - INCLUDES(listed as part of the five approved therapies for rheumatoid arthritis) -> anti-CD20
# ---
# anti-CD20 - INTERACTS_WITH(anti-CD20 targets CD20) -> CD20
# ---
# biologic/small molecule drugs - INCLUDES(listed as part of the five approved therapies for rheumatoid arthritis) -> blocking the link between the antigen-presenting cell and the T-cell
# ---
# blocking the link between the antigen-presenting cell and the T-cell - AFFECTS(therapy blocks the link between antigen-presenting cell and T-cell) -> antigen-presenting cell and T-cell link
# ---
# biologic/small molecule drugs - INCLUDES(listed as part of the five approved therapies for rheumatoid arthritis) -> anti-IL6/IL6 receptor
# ---
# anti-IL6/IL6 receptor - INTERACTS_WITH(anti-IL6/IL6 receptor targets IL6) -> IL6
# ---
# anti-IL6/IL6 receptor - INTERACTS_WITH(anti-IL6/IL6 receptor targets IL6 receptor) -> IL6 receptor
# ---
# biologic/small molecule drugs - INCLUDES(listed as part of the five approved therapies for rheumatoid arthritis) -> JAK-STAT inhibition
# ---
# JAK-STAT inhibition - INTERACTS_WITH(JAK-STAT inhibition targets the JAK-STAT pathway) -> JAK-STAT pathway
# ---
# this document - DESCRIBES(this document suggests a more precise and systematic treatment approach) -> precise and systematic treatment approach

# %% [markdown]
# ## GraphRAG
#
#  You can construct GraphRAG pipelines with the `GraphRAG` class.  At a minimum, you will need to pass the constructor an LLM and a retriever. You can optionally pass a custom prompt template. We will do so here just to provide a bit more guidance for the LLM to stick to information from our data source.
#
# Below we create `GraphRAG` objects for both the vector and vector-cypher retrievers.

# %%
from neo4j_graphrag.llm import OpenAILLM as LLM
from neo4j_graphrag.generation import RagTemplate
from neo4j_graphrag.generation.graphrag import GraphRAG

llm = LLM(model_name="gpt-4o",  model_params={"temperature": 0.0})

rag_template = RagTemplate(template='''Answer the Question using the following Context. Only respond with information mentioned in the Context. Do not inject any speculative information not mentioned. 

# Question:
{query_text}
 
# Context:
{context}

# Answer:
''', expected_inputs=['query_text', 'context'])

v_rag  = GraphRAG(llm=llm, retriever=vector_retriever, prompt_template=rag_template)
vc_rag = GraphRAG(llm=llm, retriever=vc_retriever, prompt_template=rag_template)

# %% [markdown]
# Now we can run GraphRAG and examine the outputs.

# %%
q = "How is precision medicine applied to Lupus? provide in list format."
print(f"Vector Response: \n{v_rag.search(q, retriever_config={'top_k':5}).answer}")
print("\n===========================\n")
print(f"Vector + Cypher Response: \n{vc_rag.search(q, retriever_config={'top_k':5}).answer}")
# Out:
# Vector Response:
# - Precision medicine in lupus involves a tailored approach to each patient based on genetic and epigenetic singularities.
# - It aims to influence disease pathophysiology and drug response.
# - Precision medicine seeks to optimally assess SLE patients, predict disease course, and treatment response at diagnosis.
# - Ideally, every patient would undergo an initial evaluation to profile their disease and assess the main pathophysiologic pathway.
#
# ===========================
# Retrying neo4j_graphrag.utils.rate_limit.rate_limit_handler.<locals>.wrapper.<locals>.inner_func in 1.8278108826558161 seconds as it raised RateLimitError: Rate limit exceeded: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-vcLKwx2AaSN6Mcsgr8O57A1c on tokens per min (TPM): Limit 30000, Requested 37948. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying neo4j_graphrag.utils.rate_limit.rate_limit_handler.<locals>.wrapper.<locals>.inner_func in 2.4228293641771024 seconds as it raised RateLimitError: Rate limit exceeded: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-vcLKwx2AaSN6Mcsgr8O57A1c on tokens per min (TPM): Limit 30000, Requested 37948. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/neo4j_graphrag/llm/openai_llm.py:164, in BaseOpenAILLM.invoke(self, input, message_history, system_instruction)
#     163     message_history = message_history.messages
# --> 164 response = self.client.chat.completions.create(
#     165     messages=self.get_messages(input, message_history, system_instruction),
#     166     model=self.model_name,
#     167     **self.model_params,
#     168 )
#     169 content = response.choices[0].message.content or ""
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1146 validate_response_format(response_format)
# -> 1147 return self._post(
#    1148     "/chat/completions",
#    1149     body=maybe_transform(
#    1150         {
#    1151             "messages": messages,
#    1152             "model": model,
#    1153             "audio": audio,
#    1154             "frequency_penalty": frequency_penalty,
#    1155             "function_call": function_call,
#    1156             "functions": functions,
#    1157             "logit_bias": logit_bias,
#    1158             "logprobs": logprobs,
#    1159             "max_completion_tokens": max_completion_tokens,
#    1160             "max_tokens": max_tokens,
#    1161             "metadata": metadata,
#    1162             "modalities": modalities,
#    1163             "n": n,
#    1164             "parallel_tool_calls": parallel_tool_calls,
#    1165             "prediction": prediction,
#    1166             "presence_penalty": presence_penalty,
#    1167             "prompt_cache_key": prompt_cache_key,
#    1168             "reasoning_effort": reasoning_effort,
#    1169             "response_format": response_format,
#    1170             "safety_identifier": safety_identifier,
#    1171             "seed": seed,
#    1172             "service_tier": service_tier,
#    1173             "stop": stop,
#    1174             "store": store,
#    1175             "stream": stream,
#    1176             "stream_options": stream_options,
#    1177             "temperature": temperature,
#    1178             "tool_choice": tool_choice,
#    1179             "tools": tools,
#    1180             "top_logprobs": top_logprobs,
#    1181             "top_p": top_p,
#    1182             "user": user,
#    1183             "verbosity": verbosity,
#    1184             "web_search_options": web_search_options,
#    1185         },
#    1186         completion_create_params.CompletionCreateParamsStreaming
#    1187         if stream
#    1188         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189     ),
#    1190     options=make_request_options(
#    1191         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192     ),
#    1193     cast_to=ChatCompletion,
#    1194     stream=stream or False,
#    1195     stream_cls=Stream[ChatCompletionChunk],
#    1196 )
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1256 opts = FinalRequestOptions.construct(
#    1257     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258 )
# -> 1259 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1046     log.debug("Re-raising status error")
# -> 1047     raise self._make_status_error_from_response(err.response) from None
#    1049 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-vcLKwx2AaSN6Mcsgr8O57A1c on tokens per min (TPM): Limit 30000, Requested 37948. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# During handling of the above exception, another exception occurred:
#
# LLMGenerationError                        Traceback (most recent call last)
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/neo4j_graphrag/utils/rate_limit.py:210, in rate_limit_handler.<locals>.wrapper.<locals>.inner_func()
#     209 try:
# --> 210     return func(self, *args, **kwargs)
#     211 except Exception as e:
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/neo4j_graphrag/llm/openai_llm.py:172, in BaseOpenAILLM.invoke(self, input, message_history, system_instruction)
#     171 except self.openai.OpenAIError as e:
# --> 172     raise LLMGenerationError(e)
#
# LLMGenerationError: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-vcLKwx2AaSN6Mcsgr8O57A1c on tokens per min (TPM): Limit 30000, Requested 37948. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# During handling of the above exception, another exception occurred:
#
# RateLimitError                            Traceback (most recent call last)
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/neo4j_graphrag/utils/rate_limit.py:213, in rate_limit_handler.<locals>.wrapper.<locals>.inner_func()
#     212 if is_rate_limit_error(e):
# --> 213     raise convert_to_rate_limit_error(e)
#     214 raise
#
# RateLimitError: Rate limit exceeded: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-vcLKwx2AaSN6Mcsgr8O57A1c on tokens per min (TPM): Limit 30000, Requested 37948. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[24], line 4
#       2 print(f"Vector Response: \n{v_rag.search(q, retriever_config={'top_k':5}).answer}")
#       3 print("\n===========================\n")
# ----> 4 print(f"Vector + Cypher Response: \n{vc_rag.search(q, retriever_config={'top_k':5}).answer}")
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/neo4j_graphrag/generation/graphrag.py:150, in GraphRAG.search(self, query_text, message_history, examples, retriever_config, return_context, response_fallback)
#     148     logger.debug(f"RAG: retriever_result={prettify(retriever_result)}")
#     149     logger.debug(f"RAG: prompt={prompt}")
# --> 150     llm_response = self.llm.invoke(
#     151         prompt,
#     152         message_history,
#     153         system_instruction=self.prompt_template.system_instructions,
#     154     )
#     155     answer = llm_response.content
#     156 result: dict[str, Any] = {"answer": answer}
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/neo4j_graphrag/utils/rate_limit.py:216, in rate_limit_handler.<locals>.wrapper(self, *args, **kwargs)
#     213             raise convert_to_rate_limit_error(e)
#     214         raise
# --> 216 return active_handler.handle_sync(inner_func)()
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/GitRepos/ChunkingTests/.venv/lib/python3.13/site-packages/tenacity/__init__.py:421, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
#     420     raise retry_exc.reraise()
# --> 421 raise retry_exc from fut.exception()
#
# RetryError: RetryError[<Future at 0x1299825d0 state=finished raised RateLimitError>]

# %%
q = "Can you summarize systemic lupus erythematosus (SLE)? including common effects, biomarkers, and treatments? Provide in detailed list format."

v_rag_result = v_rag.search(q, retriever_config={'top_k': 5}, return_context=True)
vc_rag_result = vc_rag.search(q, retriever_config={'top_k': 5}, return_context=True)

print(f"Vector Response: \n{v_rag_result.answer}")
print("\n===========================\n")
print(f"Vector + Cypher Response: \n{vc_rag_result.answer}")

# %%
for i in v_rag_result.retriever_result.items: print(json.dumps(eval(i.content), indent=1))

# %%
vc_ls = vc_rag_result.retriever_result.items[0].content.split('\\n---\\n')
for i in vc_ls:
    if "biomarker" in i: print(i)

# %%
vc_ls = vc_rag_result.retriever_result.items[0].content.split('\\n---\\n')
for i in vc_ls:
    if "treat" in i: print(i)

# %%
q = "Can you summarize systemic lupus erythematosus (SLE)? including common effects, biomarkers, treatments, and current challenges faced by Physicians and patients? provide in list format with details for each item."
print(f"Vector Response: \n{v_rag.search(q, retriever_config={'top_k': 5}).answer}")
print("\n===========================\n")
print(f"Vector + Cypher Response: \n{vc_rag.search(q, retriever_config={'top_k': 5}).answer}")
